# %%
# importing package
import matplotlib.pyplot as plt
import numpy as np
  
# create data
x = np.arange(5)
y1 = [0.7909164428710938,  0.8257734775543213 ,0.8809921741485596 , 0.8189539909362793, 0.847132682800293] # correlated sampling
y2 = [(1.4464843273162842 + 0.7909164428710938),  (4.807533025741577 + 0.8257734775543213), (4.089139461517334 + 0.8809921741485596),(6.429215431213379+0.8189539909362793), (2.960028648376465 + 0.847132682800293)] #cop[y based samp]

y3 = [12.611318111419678,  9.540351629257202 ,30.049304723739624 , 22.069141149520874, 13.986800909042358] #only copy based sampling
width = 0.2
  
# plot data in grouped manner of bar type
plt.bar(x, y1, width, color='red')
plt.bar(x, y2, width,bottom=y1, color='green')
plt.bar(x+0.2, y3, width, color='cyan')
plt.xticks(x, ['Q1', 'Q2', 'Q3', 'Q5', 'Q17'])
plt.xlabel("Queries")
plt.ylabel("Run Time(Seconds)")
plt.legend(["Correlated S(CS)", "Copy-Based M. after CS", "Only Copy Based M."],  loc="upper left")
plt.show()

# %%
7//2
# Out:
# 3

# %%
# create data
x = np.arange(12)
#cs
y1 = np.array([
        1.7436537742614746 , #1
        # 70,
        3.0539631843566895 , #2
        345.5729672908783 , #3
        0.20127487182617188 , #4
        436.4518024921417 , #5
        1.9721136093139648 , #6
        145.95034670829773 , #10
        0.6117873191833496 , #11
        21.131033420562744 , #16
        12.665864706039429 , #17
        60.47974705696106, #18
        78.05550336837769  #21
        ] )
#view
y2 = np.array([
         0.2745048999786377 , #1
        # 70 + 5 ,
         0.9669694900512695 , #2
         9.305120468139648 , #3
          0.31806159019470215 , #4
        27.28396224975586 , #5
         0.47266364097595215, #6
          3.0182759761810303  , #10
         0.6442887783050537 , #11
         0.8691456317901611 , #16 
         0.7945470809936523 , #17
        1.3534951210021973, #18
          1.6236648559570312  #21
      ] )
#remaining pipeline
y3 =np.array([
        18.84495496749878 - 2.1 , #1
        16.458643436431885 - 4.1 , #2 
         383.0298891067505 -  359.5 , #3
         17.593462228775024 - 0.6 , #4
        481.9255838394165 -  464.9  , #5
        21.91361165046692 - 2.7 , #6
        168.1090705394745 - 149.2 , #10
        14.202661037445068 - 1.4  , #11
        38.51559138298035  - 22.3 , #16
        29.25877285003662 - 13.6 , #17
        80.5059814453125 - 62.1, #18
        94.76698327064514 -79.9   #21
      ]) 

width = 0.5
  
# plot data in grouped manner of bar type
plt.bar(x, y1, width, color='cyan')
plt.bar(x, y2, width, bottom = y1, color='red')
plt.bar(x, y3, width,bottom = y1 + y2, color='green')
plt.xticks(x, ['Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6', 'Q10', 'Q11', 'Q16' , 'Q17', 'Q18', 'Q21'])
plt.xlabel("Queries (100 GB)")
plt.ylabel("Run Time(Seconds)")
plt.legend(["Correlated S(CS)", "View min after CS", "Remaining pipeline"],  loc="upper left")
plt.show()

# %%
# importing package
import matplotlib.pyplot as plt
import numpy as np
  
# create data
x = np.arange(12)
#cs
y1 = np.array([
        1.7436537742614746 , #1
        # 70,
        3.0539631843566895 , #2
        345.5729672908783 , #3
        0.20127487182617188 , #4
        436.4518024921417 , #5
        1.9721136093139648 , #6
        145.95034670829773 , #10
        0.6117873191833496 , #11
        21.131033420562744 , #16
        12.665864706039429 , #17
        60.47974705696106, #18
        78.05550336837769  #21
        ] )
#view
y2 = np.array([
         0.2745048999786377 , #1
        # 70 + 5 ,
         0.9669694900512695 , #2
         9.305120468139648 , #3
          0.31806159019470215 , #4
        27.28396224975586 , #5
         0.47266364097595215, #6
          3.0182759761810303  , #10
         0.6442887783050537 , #11
         0.8691456317901611 , #16 
         0.7945470809936523 , #17
        1.3534951210021973, #18
          1.6236648559570312  #21
      ] )
#remaining pipeline
y3 =np.array([
        18.84495496749878 - 2.1 , #1
        16.458643436431885 - 4.1 , #2 
         383.0298891067505 -  359.5 , #3
         17.593462228775024 - 0.6 , #4
        481.9255838394165 -  464.9  , #5
        21.91361165046692 - 2.7 , #6
        168.1090705394745 - 149.2 , #10
        14.202661037445068 - 1.4  , #11
        38.51559138298035  - 22.3 , #16
        29.25877285003662 - 13.6 , #17
        80.5059814453125 - 62.1, #18
        94.76698327064514 -79.9   #21
      ]) 


y4 =np.array([
         179.3   , #1
        69.6 , #2 
        548.0 , #3**
        33.7 , #4
        553.5   , #5
        206.4 , #6
        582.2 , #10
        32.4 , #11
        67.4 , #16
        221.2 , #17
        547, #18**
        620   #21**
      ])

y5 =np.array([
        194.8210940361023 - 179.3 , #1
        77.15006732940674 - 69.6 , #2 
         722.28 -  708.0 , #3
         50.90 - 33.7  , #4
         562.05 -  553.5   , #5
         223.23 - 206.4 , #6
         592.378 - 582.2 , #10
         43.38- 32.4  , #11
        80.23  - 67.4 , #16
        234.44 - 221.2 , #17
        50.50 -  37.5, #18
        715.23 - 705.4   #21
      ])

width = 0.3
  
# plot data in grouped manner of bar type
plt.bar(x - 0.2, y1, width, color='cyan')
plt.bar(x - 0.2, y2, width, bottom = y1, color='red')
plt.bar(x - 0.2, y3, width, bottom = y1 + y2, color='green')
plt.bar(x + 0.2, y4, width, color='red', hatch = "///")
plt.bar(x + 0.2, y5, width, bottom =y4, color='green', hatch = "///")
plt.xticks(x, ['Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6', 'Q10', 'Q11', 'Q16' , 'Q17', 'Q18', 'Q21'])
plt.xlabel("Queries (100 GB)")
plt.ylabel("Run Time(Seconds)")
plt.legend(["UN+ Correlated S(CS)", "UN+ View min after CS", "UN+ extraction time", "UN1 minimizer", "UN1 extraction time"],  loc="upper left")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
  
# create data
x = np.arange(12)
#cs
y1 = np.array([
        1.7436537742614746 , #1
        # 70,
        3.0539631843566895 , #2
        345.5729672908783 , #3
        0.20127487182617188 , #4
        436.4518024921417 , #5
        1.9721136093139648 , #6
        145.95034670829773 , #10
        0.6117873191833496 , #11
        21.131033420562744 , #16
        12.665864706039429 , #17
        60.47974705696106, #18
        78.05550336837769  #21
        ] )
#view
y2 = np.array([
         0.2745048999786377 , #1
        # 70 + 5 ,
         0.9669694900512695 , #2
         9.305120468139648 , #3
          0.31806159019470215 , #4
        27.28396224975586 , #5
         0.47266364097595215, #6
          3.0182759761810303  , #10
         0.6442887783050537 , #11
         0.8691456317901611 , #16 
         0.7945470809936523 , #17
        1.3534951210021973, #18
          1.6236648559570312  #21
      ] )
#remaining pipeline
y3 =np.array([
        18.84495496749878 - 2.1 , #1
        16.458643436431885 - 4.1 , #2 
         383.0298891067505 -  359.5 , #3
         17.593462228775024 - 0.6 , #4
        481.9255838394165 -  464.9  , #5
        21.91361165046692 - 2.7 , #6
        168.1090705394745 - 149.2 , #10
        14.202661037445068 - 1.4  , #11
        38.51559138298035  - 22.3 , #16
        29.25877285003662 - 13.6 , #17
        80.5059814453125 - 62.1, #18
        94.76698327064514 -79.9   #21
      ]) 

y4 =np.array([
        3452, #1
        433.7  , #2 
        5177 , #3
        24.2 , #4
        16493.0   , #5
        3208   , #6
        4443, #10
        209.9   , #11
        30.3       , #16
        3394 , #17
        232.8     , #18
        4787   #21
      ]) 


width = 0.5
  
# plot data in grouped manner of bar type
# plt.bar(x, y1, width, color='cyan')
# plt.bar(x, y2, width, bottom = y1, color='red')
# plt.bar(x, y3, width,bottom = y1 + y2, color='green')
# plt.bar(x, y4, width,bottom = y1 + y2 + y3, color='orange')
plt.bar(x, y4, width, color='orange')


plt.xticks(x, ['Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6', 'Q10', 'Q11', 'Q16' , 'Q17', 'Q18', 'Q21'])
plt.xlabel("Queries (100 GB)")
plt.ylabel("Run Time(Seconds)")
plt.legend(["Hash result comparator time"],  loc="upper left")
plt.show()


# updated Q1,3,5,6,10

# %%
# all time together


# importing package
import matplotlib.pyplot as plt
import numpy as np
  
# create data
x = np.arange(12)
#cs
y1 = np.array([
        1.7436537742614746 , #1
        # 70,
        3.0539631843566895 , #2
        345.5729672908783 , #3
        0.20127487182617188 , #4
        436.4518024921417 , #5
        1.9721136093139648 , #6
        145.95034670829773 , #10
        0.6117873191833496 , #11
        21.131033420562744 , #16
        12.665864706039429 , #17
        60.47974705696106, #18
        78.05550336837769  #21
        ] )
#view
y2 = np.array([
        0.2745048999786377 , #1
        # 70 + 5 ,
        0.9669694900512695 , #2
        9.305120468139648 , #3
        0.31806159019470215 , #4
        27.28396224975586 , #5
        0.47266364097595215, #6
        3.0182759761810303  , #10
        0.6442887783050537 , #11
        0.8691456317901611 , #16 
        0.7945470809936523 , #17
        1.3534951210021973, #18
        1.6236648559570312  #21
      ] )
#remaining pipeline
y3 =np.array([
        18.84495496749878 - 2.1 , #1
        16.458643436431885 - 4.1 , #2 
         383.0298891067505 -  359.5 , #3
         17.593462228775024 - 0.6 , #4
        481.9255838394165 -  464.9  , #5
        21.91361165046692 - 2.7 , #6
        168.1090705394745 - 149.2 , #10
        14.202661037445068 - 1.4  , #11
        38.51559138298035  - 22.3 , #16
        29.25877285003662 - 13.6 , #17
        80.5059814453125 - 62.1, #18
        94.76698327064514 -79.9   #21
      ]) 
y4 =np.array([
        3452, #1
        433.7  , #2 
        5177 , #3
        24.2 , #4
        16493.0   , #5
        3208   , #6
        4443, #10
        209.9   , #11
        30.3       , #16
        3394 , #17
        232.8     , #18
        4787   #21
      ]) 


width = 0.5
plt.bar(x, y1, width, color='cyan')
plt.bar(x, y2, width, bottom = y1, color='red')
plt.bar(x, y3, width,bottom = y1 + y2, color='green')
plt.bar(x, y4, width,bottom = y1 + y2 + y3, color='orange')


plt.xticks(x, ['Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6', 'Q10', 'Q11', 'Q16' , 'Q17', 'Q18', 'Q21'])
plt.xlabel("Queries (100 GB)")
plt.ylabel("Run Time(Seconds)")
plt.legend(["UN+ Correlated S", "UN+ view min", "UN+ Extraction", "UN+ Hash-Result Comp"],  loc="upper left")
plt.show()


# updated Q1,3,5,6

# %%
# all time together + comparison with unmasque


# importing package
import matplotlib.pyplot as plt
import numpy as np
  
# create data
x = np.arange(12)
#cs
y1 = np.array([
        1.7436537742614746 , #1
        # 70,
        3.0539631843566895 , #2
        345.5729672908783 , #3
        0.20127487182617188 , #4
        436.4518024921417 , #5
        1.9721136093139648 , #6
        145.95034670829773 , #10
        0.6117873191833496 , #11
        21.131033420562744 , #16
        12.665864706039429 , #17
        60.47974705696106, #18
        78.05550336837769  #21
        ] )
#view
y2 = np.array([
         0.2745048999786377 , #1
        # 70 + 5 ,
         0.9669694900512695 , #2
         9.305120468139648 , #3
          0.31806159019470215 , #4
        27.28396224975586 , #5
         0.47266364097595215, #6
          3.0182759761810303  , #10
         0.6442887783050537 , #11
         0.8691456317901611 , #16 
         0.7945470809936523 , #17
        1.3534951210021973, #18
          1.6236648559570312  #21
      ] )
#remaining pipeline
y3 =np.array([
        18.84495496749878 - 2.1 , #1
        16.458643436431885 - 4.1 , #2 
         383.0298891067505 -  359.5 , #3
         17.593462228775024 - 0.6 , #4
        481.9255838394165 -  464.9  , #5
        21.91361165046692 - 2.7 , #6
        168.1090705394745 - 149.2 , #10
        14.202661037445068 - 1.4  , #11
        38.51559138298035  - 22.3 , #16
        29.25877285003662 - 13.6 , #17
        80.5059814453125 - 62.1, #18
        94.76698327064514 -79.9   #21
      ]) 
# result comparator

y4a=np.array([
        1663.03*2, #1
        308.97*2 , #2 
        3195.143*2, #3
        363.663*2 , #4
        7942.92*2 , #5
        1430.84*2 , #6
        2281.35*2 , #10
        234.24*2  , #11
        130.84*2   , #16
        1647.21*2 , #17
        73.12*2, #18
        2480.40*2  #21
      ]) 

y4b =np.array([
        3452 - 1663.03*2, #1
        433.7  - 40 , #2 
        5177 - 2495.143*2 , #3
        24.2 - 5 , #4
        16493.0 - 7942.92*2   , #5
        3208 - 1430.84*2  , #6
        4443 - 2081.35*2 , #10
        209.9 -  20 , #11
        30.3 -  5      , #16
        3394 - 1647.21*2 , #17
        232.8 -73.12*2      , #18
        4787 - 2480.40*2  #21
      ])  

a1 =np.array([
         179.3   , #1
        69.6 , #2 
        548.0 , #3**
        33.7 , #4
        553.5   , #5
        206.4 , #6
        582.2 , #10
        32.4 , #11
        67.4 , #16
        221.2 , #17
        547, #18**
        620   #21**
      ])

a2 =np.array([
        194.8210940361023 - 179.3 , #1
        77.15006732940674 - 69.6 , #2 
         722.28 -  708.0 , #3
         50.90 - 33.7  , #4
         562.05 -  553.5   , #5
         223.23 - 206.4 , #6
         592.378 - 582.2 , #10
         43.38- 32.4  , #11
        80.23  - 67.4 , #16
        234.44 - 221.2 , #17
        50.50 -  37.5, #18
        715.23 - 705.4   #21
      ])

a3 = np.array([
        3163.89 , #1
        259.786639213562 , #2 
        5635.773955821991 , #3
        315.89284563064575 , #4
        14718.285505533218  , #5
        3232.7444083690643, #6
        4992.470921039581 , #10
        246.70489764213562 , #11
        50.67029786109924 , #16
        3203.8860330581665, #17
        30.495946168899536, #18
        5263.451494693756  #21
      ])

a4 = np.array([
        3207.408714056015 , #1
         9.74339509010315 , #2 
        5631.362746477127, #3
         8.762585401535034 , #4
         15408.552684545517 , #5
          3233.0525994300842 , #6
          4899.340217351913 , #10
        25.86381483078003 , #11
         17.17902398109436 , #16
          3184.3431804180145, #17
        17.309530019760132 , #18
         5446.708347320557  #21
      ])

width = 0.2
# UN1
plt.bar(x + 0.2, a1, width , color='red', hatch = "////", label = "UN1 Minimization" ) # old min
plt.bar(x + 0.2, a2, width, bottom =a1 , color='green', hatch = "////", label = "UN1 Extraction" ) # old extraction
plt.bar(x + 0.2, a3, width, bottom =a1 + a2 , color='yellow', hatch = "////", label = "UN1 result generation (comparison based checker)" ) 
plt.bar(x + 0.2, a4, width, bottom =a1 +a2+a3 , color='orange', hatch = "////", label = "UN1 comparison time (comparison based checker)" )   
  
# UN+
# plot data in grouped manner of bar type
plt.bar(x - 0.2, y1, width, color='cyan', label = "UN+ Correlated S" ) # copy min
plt.bar(x - 0.2, y2, width, bottom = y1, color='red', label = "UN+ view min" ) # view min
plt.bar(x - 0.2 , y3, width,bottom = y1 + y2, color='green', label = "UN+ Extraction" ) # extraction
plt.bar(x - 0.2 , y4a, width,bottom = y1 + y2 + y3, color='yellow', label = "UN+ Hash-Result generation time " ) # result comp
plt.bar(x - 0.2 , y4b, width,bottom = y1 + y2 + y3 + y4a, color='orange', label = "UN+ Hash-Result Comparison time" )
# plt.bar(x, y4, width, color='orange') 


plt.xticks(x, ['Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6', 'Q10', 'Q11', 'Q16' , 'Q17', 'Q18', 'Q21'])
plt.xlabel("Queries (100 GB)")
plt.ylabel("Run Time(Seconds)")
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
# plt.legend(["UN1 Minimization", "UN1 Extraction","UN1 result generation", "UN1 comparison time ", "UN+ Correlated S", "UN+ view min", "UN+ Extraction", "UN+ Hash-Result generation" , "UN+ Hash-Result Comparison time"],  loc="upper left")
plt.show()
# updated Q1,3,5,6

# %%
# all other time are quite negligible than the result comparison times, so to focus on them --- creating a graph with no result comparison time
# importing package
import matplotlib.pyplot as plt
import numpy as np
  
# create data
x = np.arange(12)

#cs
y1 = np.array([
        1.7436537742614746 , #1
        3.0539631843566895 , #2
        345.5729672908783 , #3
        0.20127487182617188 , #4
        436.4518024921417 , #5
        1.9721136093139648 , #6
        145.95034670829773 , #10
        0.6117873191833496 , #11
        21.131033420562744 , #16
        12.665864706039429 , #17
        60.47974705696106, #18
        78.05550336837769  #21
        ] )

#view
y2 = np.array([
         0.2745048999786377 , #1
        # 70 + 5 ,
         0.9669694900512695 , #2
         9.305120468139648 , #3
          0.31806159019470215 , #4
        27.28396224975586 , #5
         0.47266364097595215, #6
          3.0182759761810303  , #10
         0.6442887783050537 , #11
         0.8691456317901611 , #16 
         0.7945470809936523 , #17
        1.3534951210021973, #18
          1.6236648559570312  #21
      ] )

#remaining pipeline
y3 =np.array([
        18.84495496749878 - 2.1 , #1
        16.458643436431885 - 4.1 , #2 
         383.0298891067505 -  359.5 , #3
         17.593462228775024 - 0.6 , #4
        481.9255838394165 -  464.9  , #5
        21.91361165046692 - 2.7 , #6
        168.1090705394745 - 149.2 , #10
        14.202661037445068 - 1.4  , #11
        38.51559138298035  - 22.3 , #16
        29.25877285003662 - 13.6 , #17
        80.5059814453125 - 62.1, #18
        94.76698327064514 -79.9   #21
      ]) 


y4 =np.array([
         179.3   , #1
        69.6 , #2 
        548.0 , #3**
        33.7 , #4
        553.5   , #5
        206.4 , #6
        582.2 , #10
        32.4 , #11
        67.4 , #16
        221.2 , #17
        547, #18 **
        620   #21 **
      ])

y5 =np.array([
        194.8210940361023 - 179.3 , #1
        77.15006732940674 - 69.6 , #2 
         722.28 -  708.0 , #3
         50.90 - 33.7  , #4
         562.05 -  553.5   , #5
         223.23 - 206.4 , #6
         592.378 - 582.2 , #10
         43.38- 32.4  , #11
        80.23  - 67.4 , #16
        234.44 - 221.2 , #17
        50.50 -  37.5, #18
        715.23 - 705.4   #21
      ])

width = 0.4

plt.bar(x - 0.2, y1, width, color='cyan')
plt.bar(x - 0.2, y2, width, bottom = y1, color='red')
plt.bar(x - 0.2, y3, width, bottom = y1 + y2, color='green')

plt.xticks(x, ['Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6', 'Q10', 'Q11', 'Q16' , 'Q17', 'Q18', 'Q21'])
plt.xlabel("Queries (100 GB)")
plt.ylabel("Run Time (Seconds)")
plt.legend(["Correlated S(CS)", "View-min after CS", "UN+ extraction"],  loc="upper left")
plt.show()

# %%
# individual query execution times
y4 =np.array([
        1663.03, #1
        308.97 , #2 
        3195.143, #3
        363.663, #4
        7942.92   , #5
        1430.84  , #6
        2281.35, #10
        234.24  , #11
        130.84     , #16
         1647.21, #17
        73.12 , #18
        2480.40  #21
      ]) 

width = 0.5

plt.bar( x , y4 , width , color='green' )
plt.xticks(x, ['Q1', 'Q2' , 'Q3', 'Q4', 'Q5', 'Q6', 'Q10', 'Q11', 'Q16' , 'Q17', 'Q18', 'Q21'])
plt.xlabel("Queries (Database - 100 GB)")
plt.ylabel("Run Time (Seconds)")
plt.legend(["Query Execution time"],  loc="upper left")
plt.show()
